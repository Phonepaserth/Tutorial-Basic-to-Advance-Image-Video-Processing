# %% [markdown]
# ![Memories Teach](https://lh3.google.com/u/2/d/11o4JyBYhHcmz-LSt63GpOs4lfW9j39T_=w1912-h954-iv1)
#
#
# `Basic to Advance in Google colab's for image processing, pattern recognition and computer vision`
#
# [Phonepaserth SISAYKEO]
#
# Reference: visioncolab

# %% [markdown]
# # Loading and displaying color images

# %% [markdown]
# ## Download onto Google Colab

# %%
# !wget https://www.dropbox.com/s/do6b49d10ty1dyf/frutos_rojos.png
# Out:
# --2024-03-13 13:47:59--  https://www.dropbox.com/s/do6b49d10ty1dyf/frutos_rojos.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/do6b49d10ty1dyf/frutos_rojos.png [following]
# --2024-03-13 13:47:59--  https://www.dropbox.com/s/raw/do6b49d10ty1dyf/frutos_rojos.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucab90c9fd8fac2447cee7b593b0.dl.dropboxusercontent.com/cd/0/inline/CPDX7r5ZIisKzr_6WAAWq45rm-E4-LSDvGiZicSeExayI6cfDvKZ4zALki3BOiZf6tbFzSRMHgSghLsfATSu6rsMsHGk2QiDzKzbWbM3wJLcL_1UhIVo797UY_YDpWAybGo/file# [following]
# --2024-03-13 13:48:00--  https://ucab90c9fd8fac2447cee7b593b0.dl.dropboxusercontent.com/cd/0/inline/CPDX7r5ZIisKzr_6WAAWq45rm-E4-LSDvGiZicSeExayI6cfDvKZ4zALki3BOiZf6tbFzSRMHgSghLsfATSu6rsMsHGk2QiDzKzbWbM3wJLcL_1UhIVo797UY_YDpWAybGo/file
# Resolving ucab90c9fd8fac2447cee7b593b0.dl.dropboxusercontent.com (ucab90c9fd8fac2447cee7b593b0.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to ucab90c9fd8fac2447cee7b593b0.dl.dropboxusercontent.com (ucab90c9fd8fac2447cee7b593b0.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 580583 (567K) [image/png]
# Saving to: ‘frutos_rojos.png.1’
#
# frutos_rojos.png.1  100%[===================>] 566.98K  --.-KB/s    in 0.1s
#
# 2024-03-13 13:48:00 (5.59 MB/s) - ‘frutos_rojos.png.1’ saved [580583/580583]

# %% [markdown]
# #OpenCV

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# OpenCV uses BGR image format. So, when we read an image using cv2.imread() it interprets in BGR format by default. [See more](https://www.geeksforgeeks.org/convert-bgr-and-rgb-with-python-opencv/)
#
#
# OpenCV reads in images in BGR format (instead of RGB) because when OpenCV was first being developed, BGR color format was popular among camera manufacturers and image software providers. [See more](https://stackoverflow.com/questions/14556545/why-opencv-using-bgr-colour-space-instead-of-rgb)

# %%
X = cv2.imread('frutos_rojos.png')
cv2_imshow(X)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Channels

# %%
# Blue channel
B = X[:,:,0]
cv2_imshow(B)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
# Green channel
G = X[:,:,1]
cv2_imshow(G)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
# Red channel
R = X[:,:,2]
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
X = plt.imread('frutos_rojos.png')
plt.imshow(X)
plt.show()

# %%
# Red channel
R = X[:,:,0]
plt.imshow(R,cmap='gray')
plt.show()

# %%
# Green color
G = X[:,:,1]
plt.imshow(G,cmap='gray')
plt.show()

# %%
# Blue channel
B = X[:,:,1]
plt.imshow(B,cmap='gray')
plt.show()

# %% [markdown]
# # OpenCV y Matplotlib

# %%
Xbgr = cv2.imread('frutos_rojos.png')
Xrgb = cv2.cvtColor(Xbgr, cv2.COLOR_BGR2RGB) # conversion BGR to RGB
plt.imshow(Xrgb)
plt.show()

# %%
print(X.shape)
# Out:
# (512, 512, 4)
