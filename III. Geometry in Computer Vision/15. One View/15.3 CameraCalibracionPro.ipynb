# %% [markdown]
# ![Memories Teach](https://lh3.google.com/u/2/d/11o4JyBYhHcmz-LSt63GpOs4lfW9j39T_=w1912-h954-iv1)
#
#
# `Basic to Advance in Google colab's for image processing, pattern recognition and computer vision`
#
# [Phonepaserth SISAYKEO]
#
# Reference: visioncolab

# %% [markdown]
# # Environment Setup
# Download and install in Colab required packages and import libraries.

# %% [markdown]
# ## Images of the Dataset
# Downloading of X-ray images of GDXray that are used in these examples.

# %%
# !mkdir GDXray
# !mkdir GDXray/Settings

# !wget https://www.dropbox.com/s/44p6038xek4lord/S0008.zip
# !unzip S0008.zip
# !rm S0008.zip
# !mv S0008 GDXray/Settings/

print('Images of series S0008 of GDXray have been downloaded and stored in directory GDXray/.')
# Out:
# --2023-08-31 13:22:00--  https://www.dropbox.com/s/44p6038xek4lord/S0008.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/44p6038xek4lord/S0008.zip [following]
# --2023-08-31 13:22:02--  https://www.dropbox.com/s/raw/44p6038xek4lord/S0008.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd743ff075505f81df3b57a477f.dl.dropboxusercontent.com/cd/0/inline/CC2wbkFe-X3QQgL3mRpp8cMvyJ4zFDwI7jGTOt9LU-JGUZE9ejWxT-Ikz1oIS7_bkRPYrVd7RfFNWJcW727bm9DbsfAC9yBOYFur8uP4eg4LOUKVrhC6LcFomI6OrCjiAg0/file# [following]
# --2023-08-31 13:22:03--  https://ucd743ff075505f81df3b57a477f.dl.dropboxusercontent.com/cd/0/inline/CC2wbkFe-X3QQgL3mRpp8cMvyJ4zFDwI7jGTOt9LU-JGUZE9ejWxT-Ikz1oIS7_bkRPYrVd7RfFNWJcW727bm9DbsfAC9yBOYFur8uP4eg4LOUKVrhC6LcFomI6OrCjiAg0/file
# Resolving ucd743ff075505f81df3b57a477f.dl.dropboxusercontent.com (ucd743ff075505f81df3b57a477f.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6016:15::a27d:10f
# Connecting to ucd743ff075505f81df3b57a477f.dl.dropboxusercontent.com (ucd743ff075505f81df3b57a477f.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CC0HKnuGcY3QCL8KYq5PhgLeEdxcaVXatChOldXl3VOpGHpD6wp8TTDvZNWpqd5bPJ0aRxbxJq13cwLBDLyLkQMeC0C99GtbGivZekzzmmgUYc0PLxUwPdYnVGvzPgKwTpmOaK_bmBrzX6MOElwXKSFotVNUvclW5pqTS6-IMDGHfqA_atngKZp50cM9OUkvleKiyao2c_xWb-mBRhLJIz1yoJwWgYIN-r8k824Pq80RhnboxtVCNg75RooT5gBYPWtYrN2uL4uSYB7I8z8kM95uTN2HfzOZdx4QKVYV2BHb7guoQIsCchZIjmfNIED0xRIUXQnn6gnJw5uc6y8viet-cpE6NcmLeszQsIY_Dsd01w/file [following]
# --2023-08-31 13:22:04--  https://ucd743ff075505f81df3b57a477f.dl.dropboxusercontent.com/cd/0/inline2/CC0HKnuGcY3QCL8KYq5PhgLeEdxcaVXatChOldXl3VOpGHpD6wp8TTDvZNWpqd5bPJ0aRxbxJq13cwLBDLyLkQMeC0C99GtbGivZekzzmmgUYc0PLxUwPdYnVGvzPgKwTpmOaK_bmBrzX6MOElwXKSFotVNUvclW5pqTS6-IMDGHfqA_atngKZp50cM9OUkvleKiyao2c_xWb-mBRhLJIz1yoJwWgYIN-r8k824Pq80RhnboxtVCNg75RooT5gBYPWtYrN2uL4uSYB7I8z8kM95uTN2HfzOZdx4QKVYV2BHb7guoQIsCchZIjmfNIED0xRIUXQnn6gnJw5uc6y8viet-cpE6NcmLeszQsIY_Dsd01w/file
# Reusing existing connection to ucd743ff075505f81df3b57a477f.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 27617848 (26M) [application/zip]
# Saving to: ‘S0008.zip’
#
# S0008.zip           100%[===================>]  26.34M  19.5MB/s    in 1.4s
#
# 2023-08-31 13:22:06 (19.5 MB/s) - ‘S0008.zip’ saved [27617848/27617848]
#
# Archive:  S0008.zip
#    creating: S0008/
#   inflating: __MACOSX/._S0008
#   inflating: S0008/S0008_0018.png
#   inflating: __MACOSX/S0008/._S0008_0018.png
#   inflating: S0008/S0008_0009.png
#   inflating: __MACOSX/S0008/._S0008_0009.png
#   inflating: S0008/S0008_0008.png
#   inflating: __MACOSX/S0008/._S0008_0008.png
#   inflating: S0008/S0008_0012.png
#   inflating: __MACOSX/S0008/._S0008_0012.png
#   inflating: S0008/S0008_0006.png
#   inflating: __MACOSX/S0008/._S0008_0006.png
#   inflating: S0008/S0008_0007.png
#   inflating: __MACOSX/S0008/._S0008_0007.png
#   inflating: S0008/S0008_0013.png
#   inflating: __MACOSX/S0008/._S0008_0013.png
#   inflating: S0008/S0008_0005.png
#   inflating: __MACOSX/S0008/._S0008_0005.png
#   inflating: S0008/S0008_0011.png
#   inflating: __MACOSX/S0008/._S0008_0011.png
#   inflating: S0008/S0008_0010.png
#   inflating: __MACOSX/S0008/._S0008_0010.png
#   inflating: S0008/S0008_0004.png
#   inflating: __MACOSX/S0008/._S0008_0004.png
#   inflating: S0008/S0008_0014.png
#   inflating: __MACOSX/S0008/._S0008_0014.png
#   inflating: S0008/S0008_0015.png
#   inflating: __MACOSX/S0008/._S0008_0015.png
#   inflating: S0008/S0008_0001.png
#   inflating: __MACOSX/S0008/._S0008_0001.png
#   inflating: S0008/S0008_0017.png
#   inflating: __MACOSX/S0008/._S0008_0017.png
#   inflating: S0008/S0008_0003.png
#   inflating: __MACOSX/S0008/._S0008_0003.png
#   inflating: S0008/S0008_0002.png
#   inflating: __MACOSX/S0008/._S0008_0002.png
#   inflating: S0008/S0008_0016.png
#   inflating: __MACOSX/S0008/._S0008_0016.png
# Images of series S0008 of GDXray have been downloaded and stored in directory GDXray/.

# %% [markdown]
# # Geometric calibration
#
# For the calibration of an X-ray computer vision system the X-ray images of a checkerboard (series S0008 of GDXray) and the following Python code can be used. In this example a 3D Gaussian bell is superimposed onto an X-ray image in order to show how we can use the obtained geometric model to reproject 3D points onto the original image.

# %%
# Function extracted from library pyxvis, written by Christian Pieringer, Domingo Mery

def edges_on_chessboard(img, mat_p, square_size, nx=10):
    """
    Projects a the real position of the chessboard edges on the calibration pattern.

    Args:
        img (ndarray): the input image
        mat_p (ndarray): projection matrix
        square_size:
        nx:

    Returns:

    """

    x_max = 10
    y_max = 10

    # Generate a meshgrid with real locations edges on the chessboard
    mat_x = np.arange(nx) * square_size
    mat_y = mat_x.copy()
    mat_x, mat_y = np.meshgrid(mat_x, mat_y)

    # Stack all the edges as a tensor where each cell contains the coordinates
    # of the edge in the real world (chess board).
    edges = np.empty(mat_x.shape + (4,))
    edges[:, :, 0] = mat_x
    edges[:, :, 1] = mat_y
    edges[:, :, 2] = np.zeros(mat_x.shape)
    edges[:, :, 3] = np.ones(mat_y.shape)

    # Using Einstein notation to compute and reduce efficiently the matrices.
    me = np.einsum('ijk, mk->ijm', edges, mat_p).reshape(-1, 3).T
    me = h2nh(me)

    # Plot the results
    fontsize = 14
    fig = plt.figure(figsize=(12, 12))
    ax = fig.add_subplot(1, 1, 1)
    ax.imshow(img, cmap='gray')
    ax.scatter(me[0, :], me[1, :], marker='o', edgecolor='orange', facecolor='y')

    # Plot the origin of coordinate in the chessboard system
    orig = np.dot(mat_p, np.array([[0], [0], [0], [1]]))
    orig = h2nh(orig)
    ax.plot(orig[0], orig[1], 'ro')
    ax.text(orig[0], orig[1] - 20, 'O', color='w', fontsize=fontsize, weight='bold')


    orig = np.dot(mat_p, np.array([[0], [250], [0], [1]]))
    orig = h2nh(orig)
    ax.plot(orig[0], orig[1], 'bo')
    ax.text(orig[0], orig[1] - 20, 'Y', color='w', fontsize=fontsize, weight='bold')


    orig = np.dot(mat_p, np.array([[250], [0], [0], [1]]))
    orig = h2nh(orig)
    ax.plot(orig[0], orig[1], 'go')
    ax.text(orig[0], orig[1] - 20, 'X', color='w', fontsize=fontsize, weight='bold')

    ax.axis('off')
    plt.show()


def num2fixstr(x,d):
  # example num2fixstr(2,5) returns '00002'
  # example num2fixstr(19,3) returns '019'
  st = '%0*d' % (d,x)
  return st

def load_image(i):
  img = cv.imread('GDXray/Settings/S0008/S0008_'+num2fixstr(i,4)+'.png',cv.IMREAD_GRAYSCALE)
  return img

def h2nh(m):
    """
    Normalize homogeneous coordinates dividing by element of a vector.

    Args:
        m: vector

    Returns:
        The normalized vector (ndarray)

    """

    return (m / m[-1])

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np


img = load_image(6)
plt.imshow(img,cmap='gray')
plt.show()

# %%
# Termination criteria
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 30, 0.001)

nx = 10 #  number of inside corners per row
ny = 10 #  number of inside corners per column

# Prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((nx*ny, 3), np.float32)
objp[:, :2] = np.mgrid[0:nx, 0:ny].T.reshape(-1,2)
objp = 250 * objp

# Arrays to store object points and image points from all the images.
obj_points = [] # 3d point in real world space
img_points = [] # 2d points in image plane.

img_boards = []

for i in range(1, 19):

    print('Find chessboard corners in image {}: '.format(i), end='')

    img = load_image(i)
    img_h = img.copy()

    # Keep a copy of the image but using three color channels. Just for visualization.
    img = cv.cvtColor(img, cv.COLOR_GRAY2BGR)

    ret, corners = cv.findChessboardCorners(img_h, (nx, ny), flags=cv.CALIB_CB_ADAPTIVE_THRESH)

    print('{}'.format(ret))

    if ret:
        obj_points.append(objp)
        corners = cv.cornerSubPix(img_h, corners, (11, 11), (-1, -1), criteria)
        img = cv.drawChessboardCorners(img, (nx, ny), corners, ret)
        img_points.append(corners)
        img_boards.append({'img': img, 'idx': i})

# Calibrate the camera
ret, mtx, dist, rvecs, tvecs = cv.calibrateCamera(obj_points, img_points, img_h.shape[::-1], None, None)

# Show parameters
print('ret: ', ret)
print('Mtx: ', mtx)
print('Dist: ', dist)
print('Rvecs: ', rvecs)
print('Tvecs: ', tvecs)
# Out:
# Find chessboard corners in image 1: True
# Find chessboard corners in image 2: True
# Find chessboard corners in image 3: True
# Find chessboard corners in image 4: True
# Find chessboard corners in image 5: True
# Find chessboard corners in image 6: True
# Find chessboard corners in image 7: True
# Find chessboard corners in image 8: True
# Find chessboard corners in image 9: True
# Find chessboard corners in image 10: True
# Find chessboard corners in image 11: True
# Find chessboard corners in image 12: True
# Find chessboard corners in image 13: True
# Find chessboard corners in image 14: True
# Find chessboard corners in image 15: True
# Find chessboard corners in image 16: True
# Find chessboard corners in image 17: True
# Find chessboard corners in image 18: True
# ret:  1.3499339653365983
# Mtx:  [[7.87406340e+03 0.00000000e+00 1.39003949e+03]
#  [0.00000000e+00 7.87808926e+03 9.93992865e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# Dist:  [[-8.23510331e-02  2.95190451e+00  4.82577326e-03  4.55037594e-03
#   -1.23604127e+01]]
# Rvecs:  (array([[-0.03295745],
#        [-0.00222523],
#        [ 1.55874648]]), array([[0.53565422],
#        [0.56206765],
#        [1.49661413]]), array([[0.28133886],
#        [0.30837151],
#        [1.54304956]]), array([[-0.03294445],
#        [-0.00244996],
#        [ 1.55867388]]), array([[-0.02060304],
#        [-0.42493306],
#        [-0.01612628]]), array([[-0.01994881],
#        [-0.80827774],
#        [-0.01968298]]), array([[0.59836111],
#        [0.62466722],
#        [1.48027555]]), array([[0.37697369],
#        [0.4035086 ],
#        [1.52921282]]), array([[-0.03407688],
#        [-0.00610138],
#        [ 1.55891597]]), array([[-0.02229891],
#        [-0.54777747],
#        [-0.01698242]]), array([[-0.02087734],
#        [-0.89704293],
#        [-0.01996245]]), array([[-2.91673851e-02],
#        [-6.25785135e-04],
#        [ 1.55877978e+00]]), array([[0.37747   ],
#        [0.40742314],
#        [1.52874025]]), array([[0.59920243],
#        [0.62725175],
#        [1.47980162]]), array([[0.66637916],
#        [0.69381549],
#        [1.45996269]]), array([[-0.02020668],
#        [-0.80826159],
#        [-0.01954572]]), array([[0.58263397],
#        [0.60899231],
#        [1.48439637]]), array([[0.66718039],
#        [0.69315691],
#        [1.46016288]]))
# Tvecs:  (array([[ 1070.92961062],
#        [ -979.04962667],
#        [11992.18991907]]), array([[  770.90067186],
#        [ -975.54710713],
#        [11243.9025024 ]]), array([[  973.30342781],
#        [ -977.55286793],
#        [11550.32999319]]), array([[ 1070.94990928],
#        [ -979.15311739],
#        [11992.23857516]]), array([[-1061.56753946],
#        [ -953.21442   ],
#        [11513.08156523]]), array([[ -801.69982606],
#        [ -954.81755814],
#        [11176.5485517 ]]), array([[  207.51965021],
#        [ -969.25515523],
#        [11145.68627012]]), array([[  410.86347334],
#        [ -970.96732973],
#        [11395.25013938]]), array([[  572.78468983],
#        [ -973.01220644],
#        [11959.41675444]]), array([[-1491.42237415],
#        [ -948.76267542],
#        [11362.94454484]]), array([[-1223.21234421],
#        [ -950.48300319],
#        [11081.89924248]]), array([[ 1570.23233926],
#        [ -986.13140056],
#        [11969.63279919]]), array([[ 1407.4851963 ],
#        [ -984.61809391],
#        [11408.1074875 ]]), array([[ 1203.91006791],
#        [ -982.67026702],
#        [11159.3618626 ]]), array([[  631.40965847],
#        [ -851.0606052 ],
#        [11092.35588083]]), array([[ -803.30438386],
#        [-1080.71103626],
#        [11148.57310161]]), array([[  721.57382385],
#        [-1101.03813807],
#        [11166.39917753]]), array([[  627.74361949],
#        [-1100.1534094 ],
#        [11085.79073041]]))

# %%
i = 18

# Projection matrix of image i. Remember that for this example
# indexation of rotation and translation matrices starts at 0.
R, _ = cv.Rodrigues(rvecs[i-1])  # Rotation matrix 3x3
t = tvecs[i - 1]  # Translation vector 3x1

H = np.hstack([R, t])
H = np.vstack([H, np.array([0, 0, 0, 1])])

# Projection matrix
P = np.hstack([mtx, np.zeros((3, 1))])
P = np.dot(P, H)

img = load_image(i)
edges_on_chessboard(img, P, square_size=250)

# %% [markdown]
# # Superposition of a Gaussian

# %%
def multivariate_gaussian(pos, mu, sigma):
    """
    Return the multivariate Gaussian distribution on array pos.

    pos is an array constructed by packing the meshed arrays of variables
    x_1, x_2, x_3, ..., x_k into its _last_ dimension.

    [1] https://scipython.com/blog/visualizing-the-bivariate-gaussian-distribution/

    Args:
        pos:
        mu:
        sigma:

    Returns:

    """
    n = mu.shape[0]

    sigma_det = np.linalg.det(sigma)
    sigma_inv = np.linalg.inv(sigma)

    den = np.sqrt(((2 * np.pi) ** n) * sigma_det)

    # This einsum call calculates (x-mu)T.Sigma-1.(x-mu) in a vectorized
    # way across all the input variables.
    fac = np.einsum('...k, kl, ...l->...', pos - mu, sigma_inv, pos - mu)

    return np.exp(-fac / 2) / den

def gaussian_superimposition(img, mat_p, square_size, n_points=30):
    """
    This method projects a Gaussian surface on the calibration pattern.
    """

    x_max = 10
    y_max = 10

    # Generate a meshgrid with real locations edges on the chessboard
    mat_x = np.linspace(0, (x_max - 1) * square_size, n_points)
    mat_y = mat_x.copy()
    mat_x, mat_y = np.meshgrid(mat_x, mat_y)

    # Stack all the edges as a tensor where each cell contains the coordinates
    # of the edge in the real world (chess board).
    edges = np.empty(mat_x.shape + (4,))
    edges[:, :, 0] = mat_x
    edges[:, :, 1] = mat_y
    edges[:, :, 2] = np.zeros(mat_x.shape)
    edges[:, :, 3] = np.ones(mat_y.shape)

    # Mean vector and covariance matrix
    mu = np.array([1125, 1125])
    sigma = np.array([[150000, 0.0], [0.0, 150000]])

    # The distribution on the variables X, Y packed into pos.
    z = multivariate_gaussian(edges[:, :, :2], mu, sigma)
    z = (-1000 * z) / np.max(np.max(z))

    # Add Z coordinates to the edges tensor
    edges[:, :, 2] = z

    me = np.einsum('ijk, mk->ijm', edges, mat_p)

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1)
    ax.imshow(img, cmap='gray')

    # Plot lines on the x-axis first
    for ii in range(me.shape[1]):
        l = me[:, ii]
        l = l / l[:, -1][:, np.newaxis]
        ax.plot(l[:, 0], l[:, 1], '-r')

    # And, finally lines on the y-axis
    for ii in range(me.shape[0]):
        l = me[ii, :]
        l = l / l[:, -1][:, np.newaxis]
        ax.plot(l[:, 0], l[:, 1], '-r')

    ax.axis('off')

    # Plot origin of coordinates
    orig = np.dot(mat_p, np.array([[0], [0], [0], [1]]))
    orig = h2nh(orig)
    ax.plot(orig[0], orig[1], 'ro')
    ax.text(orig[0], orig[1] - 20, 'O', fontsize=14, color='y', weight='bold')

    orig = np.dot(mat_p, np.array([[0], [250], [0], [1]]))
    orig = h2nh(orig)
    ax.plot(orig[0], orig[1], 'bo')
    ax.text(orig[0], orig[1] - 20, 'Y', fontsize=14, color='y', weight='bold')

    orig = np.dot(mat_p, np.array([[250], [0], [0], [1]]))
    orig = h2nh(orig)
    ax.plot(orig[0], orig[1], 'go')
    ax.text(orig[0], orig[1] - 20, 'X', fontsize=14, color='y', weight='bold')

    plt.show()

# %%
gaussian_superimposition(img, P, square_size=250, n_points=30)

# %% [markdown]
# The output of this code is shown in last Figure. The reader that is interested in the computer graphics details of the superimposition can study the program developed under the name `gaussian_superimposition`.
