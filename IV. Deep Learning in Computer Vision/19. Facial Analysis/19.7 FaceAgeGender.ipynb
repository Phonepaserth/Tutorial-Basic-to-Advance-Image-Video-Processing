# %% [markdown]
# ![Memories Teach](https://lh3.google.com/u/2/d/11o4JyBYhHcmz-LSt63GpOs4lfW9j39T_=w1912-h954-iv1)
#
#
# `Basic to Advance in Google colab's for image processing, pattern recognition and computer vision`
#
# [Phonepaserth SISAYKEO]
#
# Reference: visioncolab

# %% [markdown]
# # Face Age & Gender

# %% [markdown]
# ## Library loading
#
# *The py-agender library works with tensorflow 1.15.5*.

# %%
# !pip install --force-reinstall tensorflow==1.15.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 110.5 MB 1.9 kB/s
# ...
#      |████████████████████████████████| 20.1 MB 59.1 MB/s
# ...
#      |████████████████████████████████| 503 kB 51.3 MB/s
# ...
#      |████████████████████████████████| 57 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 408 kB 59.3 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 55.7 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 52.7 MB/s
# ...
#      |████████████████████████████████| 75 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 59.7 MB/s
# ...
#      |████████████████████████████████| 123 kB 79.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 93 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 55.8 MB/s
# ...

# %%
# !pip install py-agender
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 188.3 MB 19 kB/s
# ...
#      |████████████████████████████████| 58.4 MB 302 kB/s
# ...
#      |████████████████████████████████| 312 kB 74.9 MB/s
# ...
#      |████████████████████████████████| 13.8 MB 51.7 MB/s
# ...
#      |████████████████████████████████| 38.2 MB 92.0 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 279 kB/s
# ...
#      |████████████████████████████████| 27.4 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 27.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 27.4 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 27.4 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 25.9 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 237 kB 89.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 140 kB 94.9 MB/s
# ...

# %%
from pyagender import PyAgender
# Out:
# Using TensorFlow backend.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-f536ed1c9483>", line 1, in <module>
#     from pyagender import PyAgender
#   File "/usr/local/lib/python3.7/dist-packages/pyagender/__init__.py", line 1, in <module>
#     from pyagender.pyagender import *
#   File "/usr/local/lib/python3.7/dist-packages/pyagender/pyagender.py", line 10, in <module>
#     from pyagender.wide_resnet import WideResNet
#   File "/usr/local/lib/python3.7/dist-packages/pyagender/wide_resnet.py", line 4, in <module>
#     from keras.models import Model
#   File "/usr/local/lib/python3.7/dist-packages/keras/__init__.py", line 3, in <module>
#     from . import utils
# ...

# %% [markdown]
# ## Testing images

# %%
# !wget https://www.dropbox.com/s/2747g2z7c4rb8ii/facesABC.zip
# !unzip facesABC.zip
# Out:
# --2022-10-11 16:31:40--  https://www.dropbox.com/s/2747g2z7c4rb8ii/facesABC.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/2747g2z7c4rb8ii/facesABC.zip [following]
# --2022-10-11 16:31:40--  https://www.dropbox.com/s/raw/2747g2z7c4rb8ii/facesABC.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca86c31bcd50c1190e15a8299a8.dl.dropboxusercontent.com/cd/0/inline/BurypyRWRidBaGXqucjCV2mFkz2IcAJGSKyasWeL5ac4HFRNei9uG_eIdkSFPR2ZOp3rBsOavckpzEGn6ioujwNfsAG4k7VKXvy5wNZvRYeD2bn_3kKqEddH4AXZOZZd4Ub4Hh-r6NC3hMm_TPXCOISXgFHnDNJD6RFMkOCOwdf22A/file# [following]
# ...

# %%
import cv2
import matplotlib.pyplot as plt


A = cv2.imread('faceA.png')
B = cv2.imread('faceB.png')
C = cv2.imread('faceC.jpg')

plt.imshow(cv2.cvtColor(A, cv2.COLOR_BGR2RGB))
plt.title('A')
plt.show()
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
plt.title('B')
plt.show()
plt.imshow(cv2.cvtColor(C, cv2.COLOR_BGR2RGB))
plt.title('C')
plt.show()

# %% [markdown]
# ## Age and Gender

# %%
agender = PyAgender()

# %%
X = B # input image
faces = agender.detect_genders_ages(X)

gender_age = agender.gender_age(X)
gender = gender_age[0]>0.5
age    = round(gender_age[1])

plt.imshow(cv2.cvtColor(X, cv2.COLOR_BGR2RGB))
plt.show()


if gender:
  print('Woman: '+str(age)+' years old')
else:
  print('Man: '+str(age)+' years old')

# %%
X = C # input image
faces = agender.detect_genders_ages(X)

gender_age = agender.gender_age(X)
gender = gender_age[0]>0.5
age    = round(gender_age[1])

plt.imshow(cv2.cvtColor(X, cv2.COLOR_BGR2RGB))
plt.show()


if gender:
  print('Woman: '+str(age)+' years old')
else:
  print('Man: '+str(age)+' years old')
